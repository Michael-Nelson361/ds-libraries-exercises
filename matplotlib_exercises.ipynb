# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# 1. Use matplotlib to plot the following equation:
#
#     $$
#     y = x^2 - x + 2
#     $$
#
#     You'll need to write the code that generates the x and y points.
#
#     Add an anotation for the point `0, 0`, as the origin.

# %%
x = pd.Series(range(-50,50))
y = x**2 - x + 2

# %%
plt.plot(x,y)
plt.annotate('origin',(0,0))
plt.grid()
plt.show;

# %% [markdown]
# 2. Create and label 4 separate charts with the following equations (choose a range for x that makes sense):
#     - $y=√x$
#     - $y=x^3$
#     - $y=2^x$
#     - $y=1/(x+1)$
#
#     You can use functions from the `math` module to help implement some of the equations above.

# %%
# Make the range
x = pd.Series(range(-50,50))

# x2 for the equations that can't go negative
x2 = pd.Series(range(50))

y1 = x**(1/2)
y1_label = r'$y=\sqrt{x}$'

y2 = x**3
y2_label = r'$y=x^3$'

y3 = 2**x2
y3_label = r'$y=2^x$'

y4 = 1/(x+1)
y4_label = r'$y=\frac{1}{x+1}$'

# %%
plt.plot(x,y1)
plt.title(y1_label)
plt.show()

# %%
plt.plot(x,y2)
plt.title(y2_label)
plt.show()

# %%
plt.plot(x2,y3)
plt.title(y3_label)
plt.show()

# %%
plt.plot(x,y4)
plt.title(y4_label)
plt.show()

# %% [markdown]
# 3. Combine the figures you created in the last step into one large figure with 4 subplots.

# %%
fig,ax = plt.subplots(2,2)

ax[0,0].plot(x,y1)
ax[0,1].plot(x,y2)
ax[1,0].plot(x2,y3)
ax[1,1].plot(x,y4)

plt.show()

# %% [markdown]
# 4. Combine the figures you created in the last step into one figure where each of the 4 equations has a different color for the points. Be sure to include a legend and an appropriate title for the figure.

# %%
plt.plot(x,y1,label=y1_label)
plt.plot(x,y2,label=y2_label)
plt.plot(x2,y3,label=y3_label)
plt.plot(x,y4,label=y4_label)

plt.legend()
plt.title('Graphing different equations (Manual Scale)')
# plt.margins(0,0.1) # Testing with margins
plt.ylim(bottom=-1,top=5)
plt.grid()

plt.show()

plt.plot(x,y1,label=y1_label)
plt.plot(x,y2,label=y2_label)
plt.plot(x2,y3,label=y3_label)
plt.plot(x,y4,label=y4_label)

plt.legend()
plt.title('Graphing different equations (Auto-scaled)')
# plt.margins(0,0.1) # Testing with margins
# plt.ylim(bottom=-0.1,top=5)
plt.grid()

plt.show()

# %% [markdown]
# 5. Make a new Jupyter notebook named `big_o_notation.ipynb`
#     - Title your chart "Big O Notation"
#     - Label your x axis "Elements"
#     - Label your y axis "Operations"
#     - Label your curves or make a legend for the curves
#     - Use LaTex notation where possible
#
#     Curves to graph
#
#     - $*y=0n+1$* and label the curve "O(1)"
#     - $y=log(n)$ and label the curve "O(log n)"
#     - $y=n$ and label the curve "O(n)"
#     - $y=n∗log(n)$ and label it "O(n log n)"
#     - $y=n^2$ and label it "O(n^2)"
#     - $y=2^n$ and label it "O(2^n)"
#     - $y=n!$ and label it "O(n!)"
#     - $y=n^n$ and label it "O(n^n)"

# %% [markdown]
# 6. **Bonus** Write the code necessary to write your name on a chart. Use box letters.

# %% [markdown]
# 7. **Bonus**: use curves for letters in your name that have curves in them.
