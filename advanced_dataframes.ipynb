# %%
import pandas as pd
import numpy as np
import env

# %% [markdown]
# ## Exercises I
#
# Run `python -m pip install pymysql` from your terminal to install pymysql.
#
# Create a notebook or python script named `advanced_dataframes` to do your work in for these exercises.
# 1. Run `python -m pip install pymysql` from your terminal to install the mysql client (any folder is fine)
# 2. cd into your exercises folder for this module and run `echo env.py >> .gitignore`

# %% [markdown]
# 3. Create a function named `get_db_url`. It should accept a username, hostname, password, and database name and return a url connection string formatted like in the example at the start of this lesson.

# %%
def get_db_url(db_name,user=env.user,password=env.password,host=env.host):
    return f'mysql+pymysql://{user}:{password}@{host}/{db_name}'

# %% [markdown]
# 4. Use your function to obtain a connection to the `employees` database.

# %%
url = get_db_url('employees')

# %% [markdown]
# 5. Once you have successfully run a query:
#
#     a. Intentionally make a typo in the database url. What kind of error message do you see?
#
#     b. Intentionally make an error in your SQL query. What does the error message look like?

# %%
pd.read_sql("""
    select *
    from employees
""",url)
# Out:
#         emp_no  birth_date first_name last_name gender   hire_date
# 0        10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1        10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2        10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4        10005  1955-01-21    Kyoichi  Maliniak      M  1989-09-12
# ...        ...         ...        ...       ...    ...         ...
# 300019  499995  1958-09-24     Dekang  Lichtner      F  1993-01-12
# 300020  499996  1953-03-07       Zito      Baaz      M  1990-09-27
# 300021  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 300022  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 300023  499999  1958-05-01     Sachin   Tsukuda      M  1997-11-30
#
# [300024 rows x 6 columns]

# %%
# # Making a typo in the database name
# url = get_db_url(env.user,env.host,env.password,'employes')

# pd.read_sql("""
#     select *
#     from employees
# """,url)

# %%
# # Making a typo in the sql query
# url = get_db_url(env.user,env.host,env.password,'employees')

# pd.read_sql("""
#     select *
#     from employes
# """,url)

# %% [markdown]
# 6. Read the `employees` and `titles` tables into two separate DataFrames.

# %%
url = get_db_url('employees')

employees = pd.read_sql("""
    select *
    from employees
""",url)

titles = pd.read_sql("""
    select *
    from titles
""",url)

# %% [markdown]
# 7. How many rows and columns do you have in each DataFrame? Is that what you expected?

# %%
employees.shape
# Out:
# (300024, 6)

# %%
titles.shape
# Out:
# (443308, 4)

# %%
# Not a lot of columns, but many rows. That was expected.

# %% [markdown]
# 8. Display the summary statistics for each DataFrame.

# %%
employees.info()
employees.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300024 entries, 0 to 300023
# Data columns (total 6 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   emp_no      300024 non-null  int64
#  1   birth_date  300024 non-null  object
#  2   first_name  300024 non-null  object
#  3   last_name   300024 non-null  object
#  4   gender      300024 non-null  object
#  5   hire_date   300024 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 13.7+ MB
#               emp_no
# count  300024.000000
# mean   253321.763392
# std    161828.235540
# min     10001.000000
# 25%     85006.750000
# 50%    249987.500000
# 75%    424993.250000
# max    499999.000000

# %%
titles.info()
titles.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 443308 entries, 0 to 443307
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   emp_no     443308 non-null  int64
#  1   title      443308 non-null  object
#  2   from_date  443308 non-null  object
#  3   to_date    443308 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 13.5+ MB
#               emp_no
# count  443308.000000
# mean   253075.034430
# std    161853.292613
# min     10001.000000
# 25%     84855.750000
# 50%    249847.500000
# 75%    424891.250000
# max    499999.000000

# %% [markdown]
# 9. How many unique titles are in the `titles` DataFrame?

# %%
titles.title.unique()
# Out:
# array(['Senior Engineer', 'Staff', 'Engineer', 'Senior Staff',
#        'Assistant Engineer', 'Technique Leader', 'Manager'], dtype=object)

# %%
titles.title.unique().shape
# Out:
# (7,)

# %%
len(titles.title.unique())
# Out:
# 7

# %% [markdown]
# 10. What is the oldest date in the `to_date` column?

# %%
titles.to_date.sort_values().head(1)
# Out:
# 16064    1985-03-01
# Name: to_date, dtype: object

# %%
titles[['to_date']].min()
# Out:
# to_date    1985-03-01
# dtype: object

# %% [markdown]
# 11. What is the most recent date in the `to_date` column?

# %%
titles.sort_values(['to_date','emp_no'],ascending=[False,True]).head(1)
# Out:
#    emp_no            title   from_date     to_date
# 0   10001  Senior Engineer  1986-06-26  9999-01-01

# %%
titles[['to_date']].max()
# Out:
# to_date    9999-01-01
# dtype: object

# %% [markdown]
# ## Exercises II
#
# 1. Copy the `users` and `roles` DataFrames from the examples above.

# %%
# Create the users DataFrame.

users = pd.DataFrame({
    'id': [1, 2, 3, 4, 5, 6],
    'name': ['bob', 'joe', 'sally', 'adam', 'jane', 'mike'],
    'role_id': [1, 2, 3, 3, np.nan, np.nan]
})
users
# Out:
#    id   name  role_id
# 0   1    bob      1.0
# 1   2    joe      2.0
# 2   3  sally      3.0
# 3   4   adam      3.0
# 4   5   jane      NaN
# 5   6   mike      NaN

# %%
# Create the roles DataFrame

roles = pd.DataFrame({
    'id': [1, 2, 3, 4],
    'name': ['admin', 'author', 'reviewer', 'commenter']
})
roles
# Out:
#    id       name
# 0   1      admin
# 1   2     author
# 2   3   reviewer
# 3   4  commenter

# %% [markdown]
# 2. What is the result of using a `right` join on the DataFrames?

# %%
users.merge(roles,how='right',left_on='role_id',right_on='id')

# In this usage, all rows from roles dataframe are kept
# From the left dataframe(users), any rows not matching the roles are dropped
# Out:
#    id_x name_x  role_id  id_y     name_y
# 0   1.0    bob      1.0     1      admin
# 1   2.0    joe      2.0     2     author
# 2   3.0  sally      3.0     3   reviewer
# 3   4.0   adam      3.0     3   reviewer
# 4   NaN    NaN      NaN     4  commenter

# %% [markdown]
# 3. What is the result of using an `outer` join on the DataFrames?

# %%
users.merge(roles,how='outer',left_on='role_id',right_on='id')

# With outer merge or join, all rows are kept
# Out:
#    id_x name_x  role_id  id_y     name_y
# 0   1.0    bob      1.0   1.0      admin
# 1   2.0    joe      2.0   2.0     author
# 2   3.0  sally      3.0   3.0   reviewer
# 3   4.0   adam      3.0   3.0   reviewer
# 4   5.0   jane      NaN   NaN        NaN
# 5   6.0   mike      NaN   NaN        NaN
# 6   NaN    NaN      NaN   4.0  commenter

# %% [markdown]
# 4. What happens if you drop the foreign keys from the DataFrames and try to merge them?

# %% [markdown]
# > Supposing you kept the basic syntax of <code>users.merge(roles,left_on='role_id',right_on='id')</code>, but you had dropped role_id, then the code would result in an error since Python would be looking for a column that no longer exists.

# %% [markdown]
# 5. Load the `mpg` dataset from PyDataset.

# %%
from pydataset import data
mpg = data('mpg') # load the dataset and store it in a variable

# %% [markdown]
# 6. Output and read the documentation for the `mpg` dataset.

# %%
data('mpg', show_doc=True) # view the documentation for the dataset
# Out:
# mpg
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Fuel economy data from 1999 and 2008 for 38 popular models of car
#
# ### Description
#
# This dataset contains a subset of the fuel economy data that the EPA makes
# available on http://fueleconomy.gov. It contains only models which had a new
# release every year between 1999 and 2008 - this was used as a proxy for the
# popularity of the car.
#
# ### Usage
#
#     data(mpg)
#
# ### Format
#
# A data frame with 234 rows and 11 variables
#
# ### Details
#
#   * manufacturer.
#
#   * model.
#
#   * displ. engine displacement, in litres
#
#   * year.
#
#   * cyl. number of cylinders
#
#   * trans. type of transmission
#
#   * drv. f = front-wheel drive, r = rear wheel drive, 4 = 4wd
#
#   * cty. city miles per gallon
#
#   * hwy. highway miles per gallon
#
#   * fl.
#
#   * class.

# %% [markdown]
# 7. How many rows and columns are in the dataset?

# %%
mpg.shape
# Out:
# (234, 11)

# %% [markdown]
# 8. Check out your column names and perform any cleanup you may want on them.

# %%
mpg.rename(columns={'cty':'city'},inplace=True)
mpg

# What does fl mean??
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# 5    compact
# ..       ...
# 230  midsize
# 231  midsize
# 232  midsize
# 233  midsize
# 234  midsize
#
# [234 rows x 11 columns]

# %% [markdown]
# 9. Display the summary statistics for the dataset.

# %%
mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 234 entries, 1 to 234
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  234 non-null    object
#  1   model         234 non-null    object
#  2   displ         234 non-null    float64
#  3   year          234 non-null    int64
#  4   cyl           234 non-null    int64
#  5   trans         234 non-null    object
#  6   drv           234 non-null    object
#  7   city          234 non-null    int64
#  8   hwy           234 non-null    int64
#  9   fl            234 non-null    object
#  10  class         234 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 21.9+ KB

# %% [markdown]
# 10. How many different manufacturers are there?

# %%
mpg['manufacturer'].nunique()
# Out:
# 15

# %% [markdown]
# 11. How many different models are there?

# %%
mpg.model.nunique()
# Out:
# 38

# %% [markdown]
# 12. Create a column named `mileage_difference` like you did in the DataFrames exercises; this column should contain the difference between highway and city mileage for each car.

# %%
mpg['mileage_difference'] = mpg.hwy - mpg.city
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  city  hwy fl    class  \
# 1         audi    a4    1.8  1999    4    auto(l5)   f    18   29  p  compact
# 2         audi    a4    1.8  1999    4  manual(m5)   f    21   29  p  compact
# 3         audi    a4    2.0  2008    4  manual(m6)   f    20   31  p  compact
# 4         audi    a4    2.0  2008    4    auto(av)   f    21   30  p  compact
# 5         audi    a4    2.8  1999    6    auto(l5)   f    16   26  p  compact
#
#    mileage_difference
# 1                  11
# 2                   8
# 3                  11
# 4                   9
# 5                  10

# %% [markdown]
# 13. Create a column named `average_mileage` like you did in the DataFrames exercises; this is the mean of the city and highway mileage.

# %%
mpg['average_mileage'] = mpg[['city','hwy']].mean(axis=1)
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  city  hwy fl    class  \
# 1         audi    a4    1.8  1999    4    auto(l5)   f    18   29  p  compact
# 2         audi    a4    1.8  1999    4  manual(m5)   f    21   29  p  compact
# 3         audi    a4    2.0  2008    4  manual(m6)   f    20   31  p  compact
# 4         audi    a4    2.0  2008    4    auto(av)   f    21   30  p  compact
# 5         audi    a4    2.8  1999    6    auto(l5)   f    16   26  p  compact
#
#    mileage_difference  average_mileage
# 1                  11             23.5
# 2                   8             25.0
# 3                  11             25.5
# 4                   9             25.5
# 5                  10             21.0

# %% [markdown]
# 14. Create a new column on the `mpg` dataset named `is_automatic` that holds boolean values denoting whether the car has an automatic transmission.

# %%
mpg['is_automatic'] = mpg.trans.str.startswith('auto')
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17   26  p
#
#        class  mileage_difference  average_mileage  is_automatic
# 1    compact                  11             23.5          True
# 2    compact                   8             25.0         False
# 3    compact                  11             25.5         False
# 4    compact                   9             25.5          True
# 5    compact                  10             21.0          True
# ..       ...                 ...              ...           ...
# 230  midsize                   9             23.5          True
# 231  midsize                   8             25.0         False
# 232  midsize                  10             21.0          True
# 233  midsize                   8             22.0         False
# 234  midsize                   9             21.5          True
#
# [234 rows x 14 columns]

# %% [markdown]
# 15. Using the `mpg` dataset, find out which which manufacturer has the best miles per gallon on average?

# %%
mpg[['manufacturer','average_mileage']].groupby('manufacturer').mean().sort_values('average_mileage',ascending=False).round(2)

# Honda gets the best average mileage
# Out:
#               average_mileage
# manufacturer
# honda                   28.50
# volkswagen              25.07
# hyundai                 22.75
# subaru                  22.43
# audi                    22.03
# toyota                  21.72
# pontiac                 21.70
# nissan                  21.35
# chevrolet               18.45
# ford                    16.68
# mercury                 15.62
# jeep                    15.56
# dodge                   15.54
# lincoln                 14.17
# land rover              14.00

# %% [markdown]
# 16. Do automatic or manual cars have better miles per gallon?

# %%
mpg[['is_automatic','average_mileage']].groupby('is_automatic').mean().round(2)

# Manual cars generally get better mileage!
# ...Well maybe not anymore but at least they did.
# Out:
#               average_mileage
# is_automatic
# False                   22.23
# True                    19.13

# %% [markdown]
# ## Exercises III
#
# 1. Use your `get_db_url` function to help you explore the data from the `chipotle` database.

# %%
url = get_db_url('chipotle')
# url

orders = pd.read_sql('''
    select *
    from orders
''',url)

orders.head()
orders['item_price'] = orders['item_price'].str.replace('$','').astype('float')
orders.head(10)
# Out:
#    id  order_id  quantity                              item_name  \
# 0   1         1         1           Chips and Fresh Tomato Salsa
# 1   2         1         1                                   Izze
# 2   3         1         1                       Nantucket Nectar
# 3   4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4   5         2         2                           Chicken Bowl
# 5   6         3         1                           Chicken Bowl
# 6   7         3         1                          Side of Chips
# 7   8         4         1                          Steak Burrito
# 8   9         4         1                       Steak Soft Tacos
# 9  10         5         1                          Steak Burrito
#
#                                                                           choice_description  \
# 0                                                                                        nan
# 1                                                                               [Clementine]
# 2                                                                                    [Apple]
# 3                                                                                        nan
# 4                 [Tomatillo-Red Chili Salsa (Hot), [Black Beans, Rice, Cheese, Sour Cream]]
# 5                [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sour Cream, Guacamole, Lettuce]]
# 6                                                                                        nan
# 7  [Tomatillo Red Chili Salsa, [Fajita Vegetables, Black Beans, Pinto Beans, Cheese, Sour...
# 8                  [Tomatillo Green Chili Salsa, [Pinto Beans, Cheese, Sour Cream, Lettuce]]
# 9        [Fresh Tomato Salsa, [Rice, Black Beans, Pinto Beans, Cheese, Sour Cream, Lettuce]]
#
#    item_price
# 0        2.39
# 1        3.39
# 2        3.39
# 3        2.39
# 4       16.98
# 5       10.98
# 6        1.69
# 7       11.75
# 8        9.25
# 9        9.25

# %% [markdown]
# 2. What is the total price for each order?

# %%
orders['quantity_price'] = orders[['item_price','quantity']].product(axis=1)
orders.head(10)
# Out:
#    id  order_id  quantity                              item_name  \
# 0   1         1         1           Chips and Fresh Tomato Salsa
# 1   2         1         1                                   Izze
# 2   3         1         1                       Nantucket Nectar
# 3   4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4   5         2         2                           Chicken Bowl
# 5   6         3         1                           Chicken Bowl
# 6   7         3         1                          Side of Chips
# 7   8         4         1                          Steak Burrito
# 8   9         4         1                       Steak Soft Tacos
# 9  10         5         1                          Steak Burrito
#
#                                                                           choice_description  \
# 0                                                                                        nan
# 1                                                                               [Clementine]
# 2                                                                                    [Apple]
# 3                                                                                        nan
# 4                 [Tomatillo-Red Chili Salsa (Hot), [Black Beans, Rice, Cheese, Sour Cream]]
# 5                [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sour Cream, Guacamole, Lettuce]]
# 6                                                                                        nan
# 7  [Tomatillo Red Chili Salsa, [Fajita Vegetables, Black Beans, Pinto Beans, Cheese, Sour...
# 8                  [Tomatillo Green Chili Salsa, [Pinto Beans, Cheese, Sour Cream, Lettuce]]
# 9        [Fresh Tomato Salsa, [Rice, Black Beans, Pinto Beans, Cheese, Sour Cream, Lettuce]]
#
#    item_price  quantity_price
# 0        2.39            2.39
# 1        3.39            3.39
# 2        3.39            3.39
# 3        2.39            2.39
# 4       16.98           33.96
# 5       10.98           10.98
# 6        1.69            1.69
# 7       11.75           11.75
# 8        9.25            9.25
# 9        9.25            9.25

# %%
pd.pivot_table(data=orders,index='order_id',values=['quantity_price'],aggfunc='sum')
# Out:
#           quantity_price
# order_id
# 1                  11.56
# 2                  33.96
# 3                  12.67
# 4                  21.00
# 5                  13.70
# ...                  ...
# 1830               23.00
# 1831               12.90
# 1832               13.20
# 1833               23.50
# 1834               28.75
#
# [1834 rows x 1 columns]

# %% [markdown]
# 3. What are the most popular 3 items?

# %%
orders.pivot_table(values='quantity',aggfunc='count',index='item_name').sort_values('quantity',ascending=False).head(3)
# Out:
#                      quantity
# item_name
# Chicken Bowl              726
# Chicken Burrito           553
# Chips and Guacamole       479

# %% [markdown]
# 4. Which item has produced the most revenue?

# %%
orders.pivot_table(values='item_price',aggfunc='sum',index='item_name').sort_values('item_price',ascending=False).head(1)
# Out:
#               item_price
# item_name
# Chicken Bowl     7342.73

# %% [markdown]
# 5. Join the `employees` and `titles` DataFrames together.

# %%
emp_titles = employees.merge(right=titles,on='emp_no')
emp_titles
# Out:
#         emp_no  birth_date first_name last_name gender   hire_date  \
# 0        10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1        10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2        10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# ...        ...         ...        ...       ...    ...         ...
# 443303  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 443304  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 443305  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 443306  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 443307  499999  1958-05-01     Sachin   Tsukuda      M  1997-11-30
#
#                   title   from_date     to_date
# 0       Senior Engineer  1986-06-26  9999-01-01
# 1                 Staff  1996-08-03  9999-01-01
# 2       Senior Engineer  1995-12-03  9999-01-01
# 3              Engineer  1986-12-01  1995-12-01
# 4       Senior Engineer  1995-12-01  9999-01-01
# ...                 ...         ...         ...
# 443303         Engineer  1987-08-30  1992-08-29
# 443304  Senior Engineer  1992-08-29  9999-01-01
# 443305     Senior Staff  1998-12-27  9999-01-01
# 443306            Staff  1993-12-27  1998-12-27
# 443307         Engineer  1997-11-30  9999-01-01
#
# [443308 rows x 9 columns]

# %% [markdown]
# 6. For each title, find the hire date of the employee that was hired most recently with that title.

# %%
emp_titles[['emp_no','hire_date','title','from_date']].groupby('title')[['hire_date']].max()
# Out:
#                      hire_date
# title
# Assistant Engineer  1999-12-24
# Engineer            2000-01-28
# Manager             1992-02-05
# Senior Engineer     2000-01-01
# Senior Staff        2000-01-13
# Staff               2000-01-12
# Technique Leader    1999-12-31

# %%
# Trying to verify the code

emp_titles.sort_values(['title','hire_date'],ascending=[True,False])
# Out:
#         emp_no  birth_date first_name     last_name gender   hire_date  \
# 212605  243702  1961-10-04   Munehiro          Luke      F  1999-12-24
# 417215  482240  1959-06-08   Guozhong        Renear      F  1999-12-12
# 201857  236390  1963-10-26  Abdelaziz  Trachtenberg      M  1999-11-17
# 80481    64369  1952-05-19      Yuqun       Negoita      M  1999-11-16
# 98439    76504  1955-07-13        Gou      Marwedel      M  1999-11-02
# ...        ...         ...        ...           ...    ...         ...
# 372447  451972  1961-12-21       Mabo        Danlos      M  1985-02-02
# 302626  404688  1961-08-09    Zhilian      Piveteau      F  1985-02-01
# 148148  110303  1956-06-08  Krassimir       Wegerle      F  1985-01-01
# 148158  110511  1957-07-08   DeForest      Hagimont      M  1985-01-01
# 148162  110725  1961-03-14  Peternela       Onuegbe      F  1985-01-01
#
#                      title   from_date     to_date
# 212605  Assistant Engineer  2000-01-07  9999-01-01
# 417215  Assistant Engineer  1999-12-12  9999-01-01
# 201857  Assistant Engineer  1999-11-17  9999-01-01
# 80481   Assistant Engineer  1999-11-19  2001-09-21
# 98439   Assistant Engineer  1999-12-05  2001-10-17
# ...                    ...         ...         ...
# 372447    Technique Leader  1988-11-30  9999-01-01
# 302626    Technique Leader  1997-07-26  9999-01-01
# 148148    Technique Leader  1988-09-09  9999-01-01
# 148158    Technique Leader  1992-04-25  9999-01-01
# 148162    Technique Leader  1989-05-06  9999-01-01
#
# [443308 rows x 9 columns]

# %%
emp_titles.groupby('title')[['hire_date']].max()
# Out:
#                      hire_date
# title
# Assistant Engineer  1999-12-24
# Engineer            2000-01-28
# Manager             1992-02-05
# Senior Engineer     2000-01-01
# Senior Staff        2000-01-13
# Staff               2000-01-12
# Technique Leader    1999-12-31

# %%
emp_titles.sort_values(['title','hire_date'],ascending=[True,False]).drop_duplicates(subset='title',keep='first')
# Out:
#         emp_no  birth_date   first_name last_name gender   hire_date  \
# 212605  243702  1961-10-04     Munehiro      Luke      F  1999-12-24
# 389997  463807  1964-06-12       Bikash    Covnot      M  2000-01-28
# 148155  110420  1963-07-27        Oscar  Ghazalie      M  1992-02-05
# 145474  108201  1955-04-14  Mariangiola   Boreale      M  2000-01-01
# 182100  222965  1959-08-07      Volkmar     Perko      F  2000-01-13
# 55137    47291  1960-09-09          Ulf    Flexer      M  2000-01-12
# 287947  294732  1960-11-07       Karlis    Orsini      M  1999-12-31
#
#                      title   from_date     to_date
# 212605  Assistant Engineer  2000-01-07  9999-01-01
# 389997            Engineer  2000-02-01  2000-05-19
# 148155             Manager  1996-08-30  9999-01-01
# 145474     Senior Engineer  2000-01-01  9999-01-01
# 182100        Senior Staff  2000-01-29  9999-01-01
# 55137                Staff  2000-01-26  9999-01-01
# 287947    Technique Leader  2000-01-28  2001-07-04

# %%
emp_titles[emp_titles.groupby(['title'])['hire_date'].transform(max) == emp_titles['hire_date']]
# Out:
# /var/folders/16/gh52g3_d1q5_w4j3fmr2r5cw0000gn/T/ipykernel_55293/1418472418.py:1: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   emp_titles[emp_titles.groupby(['title'])['hire_date'].transform(max) == emp_titles['hire_date']]
#         emp_no  birth_date   first_name last_name gender   hire_date  \
# 55137    47291  1960-09-09          Ulf    Flexer      M  2000-01-12
# 145474  108201  1955-04-14  Mariangiola   Boreale      M  2000-01-01
# 148155  110420  1963-07-27        Oscar  Ghazalie      M  1992-02-05
# 182100  222965  1959-08-07      Volkmar     Perko      F  2000-01-13
# 212605  243702  1961-10-04     Munehiro      Luke      F  1999-12-24
# 287947  294732  1960-11-07       Karlis    Orsini      M  1999-12-31
# 389997  463807  1964-06-12       Bikash    Covnot      M  2000-01-28
#
#                      title   from_date     to_date
# 55137                Staff  2000-01-26  9999-01-01
# 145474     Senior Engineer  2000-01-01  9999-01-01
# 148155             Manager  1996-08-30  9999-01-01
# 182100        Senior Staff  2000-01-29  9999-01-01
# 212605  Assistant Engineer  2000-01-07  9999-01-01
# 287947    Technique Leader  2000-01-28  2001-07-04
# 389997            Engineer  2000-02-01  2000-05-19

# %%
emp_titles.head(10)
# Out:
#    emp_no  birth_date first_name  last_name gender   hire_date  \
# 0   10001  1953-09-02     Georgi    Facello      M  1986-06-26
# 1   10002  1964-06-02    Bezalel     Simmel      F  1985-11-21
# 2   10003  1959-12-03      Parto    Bamford      M  1986-08-28
# 3   10004  1954-05-01  Chirstian    Koblick      M  1986-12-01
# 4   10004  1954-05-01  Chirstian    Koblick      M  1986-12-01
# 5   10005  1955-01-21    Kyoichi   Maliniak      M  1989-09-12
# 6   10005  1955-01-21    Kyoichi   Maliniak      M  1989-09-12
# 7   10006  1953-04-20     Anneke    Preusig      F  1989-06-02
# 8   10007  1957-05-23    Tzvetan  Zielinski      F  1989-02-10
# 9   10007  1957-05-23    Tzvetan  Zielinski      F  1989-02-10
#
#              title   from_date     to_date
# 0  Senior Engineer  1986-06-26  9999-01-01
# 1            Staff  1996-08-03  9999-01-01
# 2  Senior Engineer  1995-12-03  9999-01-01
# 3         Engineer  1986-12-01  1995-12-01
# 4  Senior Engineer  1995-12-01  9999-01-01
# 5     Senior Staff  1996-09-12  9999-01-01
# 6            Staff  1989-09-12  1996-09-12
# 7  Senior Engineer  1990-08-05  9999-01-01
# 8     Senior Staff  1996-02-11  9999-01-01
# 9            Staff  1989-02-10  1996-02-11

# %% [markdown]
# 7. Write the code necessary to create a cross tabulation of the number of titles by department. (Hint: this will involve a combination of SQL code to pull the necessary data and python/pandas code to perform the manipulations.)

# %%
# Import the two tables from the database

url = get_db_url('employees')
dept_emp = pd.read_sql('''
    select * from dept_emp
''',url)

departments = pd.read_sql('''
    select * from departments
''',url)

# %%
# Verify they imported well
# dept_emp
# departments

# %%
# Merge only the data we need

dept_title = departments.merge(right=dept_emp,on='dept_no').merge(right=titles,on='emp_no')[['dept_name','title']]
dept_title
# Out:
#                dept_name         title
# 0       Customer Service         Staff
# 1       Customer Service  Senior Staff
# 2       Customer Service         Staff
# 3       Customer Service  Senior Staff
# 4       Customer Service         Staff
# ...                  ...           ...
# 489898             Sales  Senior Staff
# 489899             Sales         Staff
# 489900             Sales         Staff
# 489901             Sales  Senior Staff
# 489902             Sales         Staff
#
# [489903 rows x 2 columns]

# %%
pd.crosstab(dept_title.dept_name,dept_title.title,margins=True)
# Out:
# title               Assistant Engineer  Engineer  Manager  Senior Engineer  \
# dept_name
# Customer Service                   298      2362        4             2027
# Development                       7769     58135        2            49326
# Finance                              0         0        2                0
# Human Resources                      0         0        2                0
# Marketing                            0         0        2                0
# Production                        6445     49649        4            42205
# Quality Management                1831     13852        4            11864
# Research                           378      2986        2             2570
# Sales                                0         0        2                0
# All                              16721    126984       24           107992
#
# title               Senior Staff   Staff  Technique Leader     All
# dept_name
# Customer Service           13925   16150               309   35075
# Development                 1247    1424              7683  125586
# Finance                    12139   13929                 0   26070
# Human Resources            12274   14342                 0   26618
# Marketing                  13940   16196                 0   30138
# Production                  1270    1478              6557  107608
# Quality Management             0       0              1795   29346
# Research                   11637   13495               393   31461
# Sales                      36191   41808                 0   78001
# All                       102623  118822             16737  489903
