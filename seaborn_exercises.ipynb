# %% [markdown]
# Use seaborn's `load_dataset` function to load the `iris` database to answer the following questions:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

iris = sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# 1. What does the distribution of petal lengths look like?

# %%
sns.displot(iris.petal_length)
plt.show()

# %% [markdown]
# 2. Is there a relationship between petal length and petal width?

# %%
# iris[['petal_length','petal_width']].corr()
sns.relplot(iris,x='petal_length',y='petal_width',hue='species')
plt.show()

# %% [markdown]
# 3. Would it be reasonable to predict species based on sepal width and sepal length? For this, you'll visualize two numeric columns through the lense of a categorical column.

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris[['sepal_length','sepal_width']].corr()
# Out:
#               sepal_length  sepal_width
# sepal_length       1.00000     -0.11757
# sepal_width       -0.11757      1.00000

# %%
# sns.catplot(iris,hue='species',x='sepal_length',y='sepal_width',palette='Set1')
# plt.show()

# Used in review
sns.relplot(data=iris,x='sepal_width',y='sepal_length',hue='species')
plt.show()

# %% [markdown]
# 4. Which features would be best used to predict species?

# %%
# Petal width and petal length would be best to predict a species
sns.pairplot(iris,hue='species',corner=True)

plt.show()

# %% [markdown]
# ---

# %% [markdown]
# 1. Load the `anscombe` dataset from seaborn. Use pandas to group the data by the `dataset` column, and calculate summary statistics for each dataset. What do you notice?

# %%
anscombe = sns.load_dataset('anscombe')

# %%
anscombe.sample(10)
# Out:
#    dataset     x     y
# 43      IV   8.0  6.89
# 21      II   5.0  4.74
# 18      II   4.0  3.10
# 0        I  10.0  8.04
# 30     III  12.0  8.15
# 25     III   9.0  7.11
# 22     III  10.0  7.46
# 5        I  14.0  9.96
# 34      IV   8.0  5.76
# 14      II   9.0  8.77

# %%
anscombe.groupby('dataset').describe(include='all').T

# x is almost consistently different in set 4 as opposed to the rest of the sets
# std changes only in y
# y-mean is different in set 3
# Sets are consistently different past the std value
# Out:
# dataset          I         II        III         IV
# x count  11.000000  11.000000  11.000000  11.000000
#   mean    9.000000   9.000000   9.000000   9.000000
#   std     3.316625   3.316625   3.316625   3.316625
#   min     4.000000   4.000000   4.000000   8.000000
#   25%     6.500000   6.500000   6.500000   8.000000
#   50%     9.000000   9.000000   9.000000   8.000000
#   75%    11.500000  11.500000  11.500000   8.000000
#   max    14.000000  14.000000  14.000000  19.000000
# y count  11.000000  11.000000  11.000000  11.000000
#   mean    7.500909   7.500909   7.500000   7.500909
#   std     2.031568   2.031657   2.030424   2.030579
#   min     4.260000   3.100000   5.390000   5.250000
#   25%     6.315000   6.695000   6.250000   6.170000
#   50%     7.580000   8.140000   7.110000   7.040000
#   75%     8.570000   8.950000   7.980000   8.190000
#   max    10.840000   9.260000  12.740000  12.500000

# %%
# sns.relplot(anscombe,x=anscombe.x,y=anscombe.y,hue=anscombe.dataset,kind='line')

# plt.show()

# sns.relplot(anscombe,x=anscombe.x,y=anscombe.y,hue=anscombe.dataset)

# plt.show()

# %% [markdown]
# - Plot the x and y values from the `anscombe` data. Each dataset should be in a separate column.

# %%
sns.relplot(anscombe,x='x',y='y',col='dataset')

plt.show()

# %% [markdown]
# 2. Load the `InsectSprays` dataset from pydataset and read it's documentation. Create a boxplot that shows the effectiveness of the different insect sprays.

# %%
from pydataset import data
insect_sprays = data('InsectSprays')

data('InsectSprays',show_doc=True)
# Out:
# InsectSprays
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Effectiveness of Insect Sprays
#
# ### Description
#
# The counts of insects in agricultural experimental units treated with
# different insecticides.
#
# ### Usage
#
#     InsectSprays
#
# ### Format
#
# A data frame with 72 observations on 2 variables.
#
# [,1]
#
# count
#
# numeric
#
# Insect count
#
# [,2]
#
# spray
#
# factor
#
# The type of spray
#
# ### Source
#
# Beall, G., (1942) The Transformation of data from entomological field
# experiments, _Biometrika_, **29**, 243–262.
#
# ### References
#
# McNeil, D. (1977) _Interactive Data Analysis_. New York: Wiley.
#
# ### Examples
#
#     require(stats); require(graphics)
#     boxplot(count ~ spray, data = InsectSprays,
#             xlab = "Type of spray", ylab = "Insect count",
#             main = "InsectSprays data", varwidth = TRUE, col = "lightgray")
#     fm1 <- aov(count ~ spray, data = InsectSprays)
# ...

# %%
insect_sprays.head(10)
# Out:
#     count spray
# 1      10     A
# 2       7     A
# 3      20     A
# 4      14     A
# 5      14     A
# 6      12     A
# 7      10     A
# 8      23     A
# 9      17     A
# 10     20     A

# %%
sns.boxplot(insect_sprays,y='count',x='spray')

plt.show()

# %% [markdown]
# 3. Load the `swiss` dataset from pydataset and read it's documentation.

# %%
swiss = data('swiss')
data('swiss',show_doc=True)
# Out:
# swiss
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Swiss Fertility and Socioeconomic Indicators (1888) Data
#
# ### Description
#
# Standardized fertility measure and socio-economic indicators for each of 47
# French-speaking provinces of Switzerland at about 1888.
#
# ### Usage
#
#     data(swiss)
#
# ### Format
#
# A data frame with 47 observations on 6 variables, each of which is in percent,
# i.e., in [0,100].
#
# [,1] Fertility Ig, "common standardized fertility measure" [,2] Agriculture
# [,3] Examination nation [,4] Education [,5] Catholic [,6] Infant.Mortality
# live births who live less than 1 year.
#
# All variables but 'Fert' give proportions of the population.
#
# ### Source
#
# Project "16P5", pages 549-551 in
#
# Mosteller, F. and Tukey, J. W. (1977) “Data Analysis and Regression: A Second
# Course in Statistics”. Addison-Wesley, Reading Mass.
#
# ...

# %% [markdown]
# Create visualizations to answer the following questions:
# - Create an attribute named `is_catholic` that holds a boolean value of whether or not the province is Catholic. (Choose a cutoff point for what constitutes catholic)

# %%
# In order to determine what we'll constitue Catholic to be, let's look at the distribution
swiss.Catholic.hist(bins=5)

plt.show()

# %%
# swiss.Catholic.mean()

# %%
# Let's make the province to be Catholic if more than 50% of the population is Catholic
swiss['is_catholic'] = swiss.Catholic > 50

# %% [markdown]
# - Does whether or not a province is Catholic influence fertility?

# %%
swiss[['Fertility','Catholic']].corr()
# Out:
#            Fertility  Catholic
# Fertility   1.000000  0.463685
# Catholic    0.463685  1.000000

# %%
sns.relplot(swiss,y='Fertility',x='Catholic',hue='is_catholic')

plt.show()

# There doesn't appear to be a strong correlation between being Catholicism and fertility
# That being said, fertility does seem to be higher among more predominantly Catholic provinces

# %%
# From the review
# This looks better and shows a better relation
sns.boxplot(swiss, x='is_catholic',y='Fertility');

# %% [markdown]
# - What measure correlates most strongly with fertility?

# %%
swiss.iloc[:,:len(swiss.columns)-1].corr()[:1]
# .iloc selects all index values and leaves off the last column
# Last bracket drops all resulting indexes except first one

# Accordingly, education correlates most strongly with fertility, although it's a negative correlation
# Out:
#            Fertility  Agriculture  Examination  Education  Catholic  \
# Fertility        1.0     0.353079    -0.645883  -0.663789  0.463685
#
#            Infant.Mortality
# Fertility          0.416556

# %%
sns.heatmap(swiss.corr()[:1],cmap='Reds',annot=True)
# Out:
# <Axes: >

# %% [markdown]
# 4. Load the `chipotle` dataset from SQL, create a bar chart that shows the 4 most popular items and the revenue produced by each.

# %%
import my_functions as mf

url = mf.get_db_url('chipotle')

# %%
chipotle = pd.read_sql('select * from orders',url)
chipotle.head()
# Out:
#    id  order_id  quantity                              item_name  \
# 0   1         1         1           Chips and Fresh Tomato Salsa
# 1   2         1         1                                   Izze
# 2   3         1         1                       Nantucket Nectar
# 3   4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4   5         2         2                           Chicken Bowl
#
#                                                            choice_description  \
# 0                                                                         nan
# 1                                                                [Clementine]
# 2                                                                     [Apple]
# 3                                                                         nan
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans, Rice, Cheese, Sour Cream]]
#
#   item_price
# 0     $2.39
# 1     $3.39
# 2     $3.39
# 3     $2.39
# 4    $16.98

# %%
# Fix the item_price
chipotle['item_price'] = chipotle.item_price.str.strip('$').astype('float')
chipotle.head()
# Out:
#    id  order_id  quantity                              item_name  \
# 0   1         1         1           Chips and Fresh Tomato Salsa
# 1   2         1         1                                   Izze
# 2   3         1         1                       Nantucket Nectar
# 3   4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4   5         2         2                           Chicken Bowl
#
#                                                            choice_description  \
# 0                                                                         nan
# 1                                                                [Clementine]
# 2                                                                     [Apple]
# 3                                                                         nan
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans, Rice, Cheese, Sour Cream]]
#
#    item_price
# 0        2.39
# 1        3.39
# 2        3.39
# 3        2.39
# 4       16.98

# %%
# Filter down to 4 popular items
popular_items = chipotle.groupby('item_name').sum('quantity').nlargest(4,columns='quantity')
popular_items
# Out:
#                           id  order_id  quantity  item_price
# item_name
# Chicken Bowl         1780635    713926       761     7342.73
# Chicken Burrito      1238770    497303       591     5575.82
# Chips and Guacamole  1122252    449959       506     2201.04
# Steak Burrito         818163    328437       386     3851.43

# %%
# Turn it into a graph!
sns.barplot(popular_items,y=popular_items.index,x='item_price')

plt.show()

# %% [markdown]
# 5. Load the `sleepstudy` dataset from pydataset and read it's documentation. Use seaborn to create a line chart of all the individual subject's reaction times and a more prominant line showing the average change in reaction time.

# %%
sleepstudy = data('sleepstudy')
# data('sleepstudy',show_doc=True)

# %%
sleepstudy.sample(10)
# Out:
#      Reaction  Days  Subject
# 178  343.2199     7      372
# 63   276.7693     2      333
# 15   207.7161     4      309
# 148  348.1229     7      369
# 117  379.4445     6      350
# 91   312.3666     0      337
# 29   261.0125     8      310
# 179  369.1417     8      372
# 133  326.8785     2      352
# 64   299.8097     3      333

# %%
# See how many subjects we have
sleepstudy.Subject.nunique()
# Out:
# 18

# %%
# See how many days we have
sleepstudy.Days.nunique()
# Out:
# 10

# %%
sleepstudy.Subject = sleepstudy.Subject.astype('str')

# %%
plt.figure(figsize=(12,8))
sns.lineplot(data=sleepstudy,y='Reaction',x='Days',hue='Subject')
sns.lineplot(data=sleepstudy,y='Reaction',x='Days',c='black',linewidth=6)
# sns.move_legend()
plt.show()
